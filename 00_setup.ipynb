# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha0948/BrainTumorSegmentation/blob/main/00_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install nibabel opencv-python albumentations tqdm
# Out:
# Mounted at /content/drive
# ...

# %%
import os
base = "/content/drive/MyDrive/BrainTumorSegmentation/data/raw"
os.makedirs(base, exist_ok=True)
# create a dummy text to mark that you will put data here
open(os.path.join(base, "READM.txt"),"w").write("Put BRaTS .nii.gz folders here")
print("placeholder created:", base)
# Out:
# placeholder created: /content/drive/MyDrive/BrainTumorSegmentation/data/raw
